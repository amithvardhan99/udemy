# %%
import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt  
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("C:/Users/amith/Documents/GitHub/udemy/17 - Sculpting Your Body Fat Estimator App on Microsoft Azure/bodyfat.csv")
df.head()
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# 2  38.9   24.0    28.8     25.2   16.6
# 3  37.3   22.8    32.4     29.4   18.2
# 4  42.2   24.0    32.2     27.7   17.7

# %%
df.to_

# %%
ss = StandardScaler()
hk = ss.fit_transform(df["Density"].to_numpy().reshape(-1,1))
# Out:
# array([[ 0.80164696],
#        [ 1.56506057],
#        [-0.74623993],
#        [ 1.02803858],
#        [-1.13584412],
#        [-0.28292685],
#        [-0.03547554],
#        [ 0.78058728],
#        [ 1.81251187],
#        [ 0.87535586],
#        [ 1.44396737],
#        [ 1.34919879],
#        [-0.22501271],
#        [-0.26713208],
#        [-0.37769543],
#        [-0.23027763],
#        [-1.17269857],
#        [-0.46193418],
#        [ 0.34886372],
#        [ 0.28568466],
#        [-0.0249457 ],
#        [ 0.44363231],
#        [ 0.39624801],
#        [ 0.14879671],
#        [ 0.59105011],
#        [ 1.87042601],
#        [ 1.34393387],
#        [-0.46193418],
#        [ 1.86516109],
#        [ 1.23337052],
#        [ 0.84376633],
#        [ 1.61244486],
#        [ 0.8595611 ],
#        [-0.28292685],
#        [-1.54124306],
#        [-2.39416033],
#        [-0.61988182],
#        [-1.10425459],
#        [-1.86240327],
#        [-1.56756767],
#        [-1.78342945],
# ...

# %%
sns.kdeplot(df["Abdomen"])
# Out:
# <Axes: xlabel='Abdomen', ylabel='Density'>
